# %% [markdown]
# <a href="https://colab.research.google.com/github/LakshmiPalaka/Playwright/blob/main/Important_Interview_Questions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # API Testing Questions
# =======================
# 1. What is API testing
#
# 2. Tell me some HTTP Methods
#
# 3. What is the different between PUT vs Patch
#
# 4. Can create some resouces with Put Request insted if POST
#
# 5. Tell me Status codes
#
#  200
#  201
#  202
#  204
#
#  400
#  401
#  402
#  403
#  404
#  409
#
#
#  500
#  501
#  503
#
# 6. Have you tested 500 series status codes
#
# 7. 401 vs 403
#
# 8. Athorization vs Athentication
#
# 9. When you will get 401
#
# 10. What is Athorization techniques
#
# 11. Oauth 1.0 vs Oauth 2.0
#
# 12. Tell me some Generic tests you perform while doing API testing
#
#  Get  - 200
#  Get - 400
#  Get - 401
#  Get - 403
#
# 13. What is URI
#
# 14. What is URL
#
# 15. What is Protocal
#
# 16. What is Path vs Query params
#
# 17. To trigger APIs What details need about API
#
# 18. What you are going verify from API response
#
# 19. What is the difference between web API and Web Services
#
# 20. What is the different between Rest services and SOAP
#
# 21. What are different architecture styles
#
# 22. Common Test in API
#
# 23. Types of testing you can perform using API
#
# 24. What are features of Postman
#
# 25. what cURL
#
# 26. How to share collections
#
# 27. How to Import collections
#
# 28. How to do API test Automation Using PostMan
#
# 29. What is the collection level Variuables how to create
#
# 30. What is global veriables, how to create
#
# 31. What is environment level variables, how to create it.
#
# 32. What are other tools you know for API testing
#
# 33. What are tools for API test Automation, Which one you are using.

# %% [markdown]
# # Agile
# --------
#
# 1. What is difference between traditional models and Agile
#
# 2. Product Backlog Items vs Sprint Backlog Items
#
# 3. What is your sprint duration
#
#    2 weeks
#
# 4. How many members are there in your teams
#
#   8 members
#
# 	 SM
# 	 PO
# 	 2 testers
# 	 2 Backend
# 	 2 front end
#
# 	10 members
#
# 	 SM
# 	 PO
# 	 2 testers
# 	 2 Backend
# 	 2 front end
# 	 2 Shared resources
#
# 5. What are the Agile cermonies you will attend in your company
#
# - Sprint
#
# - Sprint Planning
#
# - Sprint review
#
# - Sprint retrospective
#
# - DSM
#
# - Grooming / Backlog refinement
#
# - Estimation
#
# 6. What are Agile events  / Meeting
#
# - Sprint
#
# - Sprint Planning
#
# - Sprint review
#
# - Sprint retrospective
#
# - DSM
#
# - Grooming / Backlog refinement
#
# - Estimation
#
# 7. What you do in sprint planning meeting
#
# 8. What you do in Sprint retrospective
#
# 9. What you do in DSM
#
# 10. What you do in Sprint review Meeting
#
# 11. Sprint review vs Sprint retrospective
#
# 12. Backlog refinement
#
# 13. How will you estimate the user stories
#
# - Story points
#
# - 1 2 3 5 8
#
# - Poker
#
# - T shirting
#
# 14. Velocity
#
# 15. Sprint Burndown chart

# %% [markdown]
# # Manual testing
# =========================
#
# 16. Can you explain testing Principles
#
# 17. What are quality standards you follow in your company
#
# 	- ISO
# 	- IEEE
# 	- IEEE 829
#
# 18. What are sections/ Attributes will be there in you test plan
#
# 19. Entry vs Exit creteria
#
# 20. Tell 3 important things in test plan
#
# 21. Levels / Testing Pyramid
#
# 22. Alpha vs beta testing
#
# 23. Types of testing
#
#     - Based on source code
#
#     - Based objectives
#
# 24. Functional Testing
#
# 25. Smoke vs Sanity
#
# 26. Regression Vs Retesting
#
# 27. What is performance testing , different types
#
# 28. Load testing
#
# 29. What are the Attributes in test case document **
#
# 30. Can test cases for Pen / ATM / Login / Any specified
#
# 31. Positive test cases and Negative test cases
#
# 32. What are different test case design Techniques
#
# 33. can you please equivalance partition technique with example
#
#     - Where you used in your Project
#
# 34. can you please explain BVA technique with example
#
#     - Where you used in your Project
#
# 35. can you please explain DT technique with example
#
#     - Where you used in your Project
#
# 36. How will ensure your test environment set up
#
# 37. Types of Defects
#
# 38. Severity and Priority
#
# 39. Example for Low severity and High priority
#
# 40. Can you tell me what is critical bug that you found in your project
#
# 41. What attributes in defect reporting / What are info captured while defect reporting
#
# 42. Can please explain defect life cycle in your Project
#
# 43. What is mean by deffered
#
# 44. If developer not accepting the bug what you do?
#
# 45. Defect Leakage, Have you leaked any defect to production
#
# 46. RCA - root cause Analysis
#
# 47. Defect Traiage
#
# 48. Hot fix
#
# 49. Intermittent defect /issue
#
# 50. Where you will Write test cases
#
# 51. When you will write Test cases ( Before develop or after develop)
#
# 52. Where you will report the defect
#
# 53. What are different environments available in your project
#
#     - Dev , QA , Preprod, Prod
#
#     - Dev , QA , UAT, Preprod, Prod
#
# 54. What are test closure activities
#
# 55. When you will stop the testing
#
# 56. What is the Test management tool / Project Management/ Defect Management tool.

# %% [markdown]
# Automation & Playwright:
# ========================
#
# 1. Tell me some of your day to day to activities w.r.t.Automation
#
# 2. How to choose the automation tool / If i give chance on what basis you will choose the tool.
#
# 3. Selenium vs Playwright
#
# 4. Cypress vs Playwright
#
# 5. Why we need to automation
#
# 6. What kind of Tests you choose for automation
#    / Are going to automate all tests written by Manaul tester.
#
# 7. Whatb are pre-requisites to Install playwright
#
# 8. How to Install Playwright
#
# 10. tell me 10 methods that you in playwright
#
# 12. Assertions in Playwright
#
# 13. How to Verify the title of the Page
#
# 14. How to Verify the current url
#
# 15. How to Launch the URL
#
# 16. What the purpose of async and await
#
# 17. How will you run your tests
#
# 18. Tell Me some cli commands
#
# - single file
# - Specify the browser
# - Specify the worker
# - specify the retries
# - line number specify
# - single test
#
# 19. How will you debug the tests
#
# 20. How to run tests in sequential manner
#
# 21. What are configurations done your project
#
# 22. What is default test timeout
#
# 23. What is the default expect timeout
#
# 24. Your project folder structure
#
# 25. What is the diffrence between npm and npx
#
# 26. What is the current version playwright
#
# 27. Annotations in playwright
#
# 28. How to group the tests
#
# 29. What are hooks in playwright
#
# 30. what is diffrence between presssequentially and fill
#
# 31. Fill vs Type
#
# 32. How to do the right click
#
# 33. what is the method for double click
#
# 34. How to refresh the page
#
# 35. How to navigate previous and next page
#
# 36. How to Select the drop down values
#
# 37. How to do the drag and drop
#
# 38. How to do the scrolling
#
# 39. How to work with alerts
#
# 40. How to create a contexts
#
# 41. What are fixtures in Playwright
#
# 42. Different between toBevisble() and isVisible()
#
# 43. How to work with Iframe Elements
#
# 45. What are advantages of POM
#
# 46. How to Implement POM
#
# 47. How to Work with Multiple Tabs
#
# 48. How to Upload file
#
# 49. How to download file
#
# 50. How to take the screenshot for single Element.
